% %%
load('recon3d_qflux.mat')

% %%
% subsystems
unique_subsystems = unique(model.subSystems);
for a = 1:length(unique_subsystems)
    genes = {};
    for i = 1:length(model.rxns)
        if strcmp(model.subSystems{i},unique_subsystems{a})
            for geneid = find(model.rxnGeneMat(i,:))
                if ~any(strcmp(genes,model.geneSymbols{geneid}))
                    genes{end+1} = model.geneSymbols{geneid};
                end
            end
        end
    end
    fprintf('%d\t%s\n',length(genes),unique_subsystems{a})
end
% Out:
% 15	Alanine and aspartate metabolism
% 5	Alkaloid synthesis
% 39	Aminoacyl-tRNA biosynthesis
% 31	Aminosugar metabolism
% 51	Androgen and estrogen synthesis and metabolism
% 84	Arachidonic acid metabolism
% 37	Arginine and proline metabolism
% 22	Beta-Alanine metabolism
% 58	Bile acid synthesis
% 2	Biotin metabolism
% 13	Blood group synthesis
% 11	Butanoate metabolism
% 3	C5-branched dibasic acid metabolism
% 37	Cholesterol metabolism
% 10	Chondroitin sulfate degradation
% 41	Chondroitin synthesis
% 28	Citric acid cycle
% 11	CoA catabolism
% 11	CoA synthesis
% 16	Cytochrome metabolism
% 3	D-alanine metabolism
% 0	Dietary fiber binding
% 55	Drug metabolism
% 97	Eicosanoid metabolism
% 40	Exchange/demand reaction
% 94	Fatty acid oxidation
% 70	Fatty acid synthesis
% 18	Folate metabolism
% 36	Fructose and mannose metabolism
% 19	Galactose metabolism
% 21	Glutamate metabolism
% 25	Glutathione metabolism
% 163	Glycerophospholipid metabolism
% 30	Glycine, serine, alanine, and threonine metabolism
% 81	Glycolysis/gluconeogenesis
% 58	Glycosphingolipid metabolism
% 30	Glyoxylate and dicarboxylate metabolism
% 5	Heme degradation
% 13	Heme synthesis
% 6	Heparan sulfate degradation
% 0	Hippurate metabolism
% 37	Histidine metabolism
% 7	Hyaluronan metabolism
% 105	Inositol phosphate metabolism
% 11	Keratan sulfate degradation
% 21	Keratan sulfate synthesis
% 64	Leukotriene metabolism
% 15	Limonene and pinene degradation
% 58	Linoleate metabolism
% 4	Lipoate metabolism
% 52	Lysine metabolism
% 41	Methionine and cysteine metabolism
% 1043	Miscellaneous
% 15	N-glycan degradation
% 17	N-glycan metabolism
% 36	N-glycan synthesis
% 35	NAD metabolism
% 115	Nucleotide interconversion
% 69	Nucleotide metabolism
% 2	Nucleotide salvage pathway
% 2	Nucleotide sugar metabolism
% 24	O-glycan metabolism
% 99	Oxidative phosphorylation
% 26	Pentose phosphate pathway
% 0	Peptide metabolism
% 36	Phenylalanine metabolism
% 40	Phosphatidylinositol phosphate metabolism
% 50	Propanoate metabolism
% 1	Protein assembly
% 18	Protein degradation
% 0	Protein formation
% 197	Protein modification
% 33	Purine catabolism
% 9	Purine synthesis
% 29	Pyrimidine catabolism
% 22	Pyrimidine synthesis
% 42	Pyruvate metabolism
% 0	R group synthesis
% 9	ROS detoxification
% 27	Selenoamino acid metabolism
% 125	Sphingolipid metabolism
% 7	Squalene and cholesterol synthesis
% 31	Starch and sucrose metabolism
% 61	Steroid metabolism
% 2	Stilbene, coumarine and lignin synthesis
% 6	Taurine and hypotaurine metabolism
% 19	Tetrahydrobiopterin metabolism
% 5	Thiamine metabolism
% 29	Transport, endoplasmic reticular
% 317	Transport, extracellular
% 28	Transport, golgi apparatus
% 36	Transport, lysosomal
% 61	Transport, mitochondrial
% 54	Transport, nuclear
% 25	Transport, peroxisomal
% 29	Triacylglycerol synthesis
% 0	Triglycerides formation
% 77	Tryptophan metabolism
% 72	Tyrosine metabolism
% 10	Ubiquinone synthesis
% 26	Urea cycle
% 43	Valine, leucine, and isoleucine metabolism
% 75	Vitamin A metabolism
% 1	Vitamin B12 metabolism
% 10	Vitamin B2 metabolism
% 4	Vitamin B6 metabolism
% 13	Vitamin C metabolism
% 6	Vitamin D metabolism
% 33	Vitamin E metabolism
% 1	Vitamin K metabolism
% 91	Xenobiotics metabolism

% %%
% nadp+ to nadph (c or m)
reactions = [];
for i = 1:length(model.rxns)
    if (full(model.S(strcmp(model.mets,'nadp[c]'),i)) < 0 && full(model.S(strcmp(model.mets,'nadph[c]'),i)) > 0 && model.ub(i) > 0) || (full(model.S(strcmp(model.mets,'nadp[c]'),i)) > 0 && full(model.S(strcmp(model.mets,'nadph[c]'),i)) < 0 && model.lb(i) < 0) || (full(model.S(strcmp(model.mets,'nadp[m]'),i)) < 0 && full(model.S(strcmp(model.mets,'nadph[m]'),i)) > 0 && model.ub(i) > 0) || (full(model.S(strcmp(model.mets,'nadp[m]'),i)) > 0 && full(model.S(strcmp(model.mets,'nadph[m]'),i)) < 0 && model.lb(i) < 0) 
        reactions(end+1) = i;
    end
end
genes = {};
for i = reactions
    for geneid = find(model.rxnGeneMat(i,:))
        if ~any(strcmp(genes,model.geneSymbols{geneid}))
            genes{end+1} = model.geneSymbols{geneid};
        end
    end
end
disp(length(genes))
% Out:
%    134

% %%
% nadph to nadp+ (c or m)
reactions = [];
for i = 1:length(model.rxns)
    if (full(model.S(strcmp(model.mets,'nadp[c]'),i)) > 0 && full(model.S(strcmp(model.mets,'nadph[c]'),i)) < 0 && model.ub(i) > 0) || (full(model.S(strcmp(model.mets,'nadp[c]'),i)) < 0 && full(model.S(strcmp(model.mets,'nadph[c]'),i)) > 0 && model.lb(i) < 0) || (full(model.S(strcmp(model.mets,'nadp[m]'),i)) > 0 && full(model.S(strcmp(model.mets,'nadph[m]'),i)) < 0 && model.ub(i) > 0) || (full(model.S(strcmp(model.mets,'nadp[m]'),i)) < 0 && full(model.S(strcmp(model.mets,'nadph[m]'),i)) > 0 && model.lb(i) < 0) 
        reactions(end+1) = i;
    end
end
genes = {};
for i = reactions
    for geneid = find(model.rxnGeneMat(i,:))
        if ~any(strcmp(genes,model.geneSymbols{geneid}))
            genes{end+1} = model.geneSymbols{geneid};
        end
    end
end
disp(length(genes))
% Out:
%    216

% %%
% nad+ to nadh (c or m)
reactions = [];
for i = 1:length(model.rxns)
    if (full(model.S(strcmp(model.mets,'nad[c]'),i)) < 0 && full(model.S(strcmp(model.mets,'nadh[c]'),i)) > 0 && model.ub(i) > 0) || (full(model.S(strcmp(model.mets,'nad[c]'),i)) > 0 && full(model.S(strcmp(model.mets,'nadh[c]'),i)) < 0 && model.lb(i) < 0) || (full(model.S(strcmp(model.mets,'nad[m]'),i)) < 0 && full(model.S(strcmp(model.mets,'nadh[m]'),i)) > 0 && model.ub(i) > 0) || (full(model.S(strcmp(model.mets,'nad[m]'),i)) > 0 && full(model.S(strcmp(model.mets,'nadh[m]'),i)) < 0 && model.lb(i) < 0) 
        reactions(end+1) = i;
    end
end
genes = {};
for i = reactions
    for geneid = find(model.rxnGeneMat(i,:))
        if ~any(strcmp(genes,model.geneSymbols{geneid}))
            genes{end+1} = model.geneSymbols{geneid};
        end
    end
end
disp(length(genes))
% Out:
%    134

% %%
% nadh to nad+ (c or m)
reactions = [];
for i = 1:length(model.rxns)
    if (full(model.S(strcmp(model.mets,'nad[c]'),i)) > 0 && full(model.S(strcmp(model.mets,'nadh[c]'),i)) < 0 && model.ub(i) > 0) || (full(model.S(strcmp(model.mets,'nad[c]'),i)) < 0 && full(model.S(strcmp(model.mets,'nadh[c]'),i)) > 0 && model.lb(i) < 0) || (full(model.S(strcmp(model.mets,'nad[m]'),i)) > 0 && full(model.S(strcmp(model.mets,'nadh[m]'),i)) < 0 && model.ub(i) > 0) || (full(model.S(strcmp(model.mets,'nad[m]'),i)) < 0 && full(model.S(strcmp(model.mets,'nadh[m]'),i)) > 0 && model.lb(i) < 0) 
        reactions(end+1) = i;
    end
end
genes = {};
for i = reactions
    for geneid = find(model.rxnGeneMat(i,:))
        if ~any(strcmp(genes,model.geneSymbols{geneid}))
            genes{end+1} = model.geneSymbols{geneid};
        end
    end
end
disp(length(genes))
% Out:
%    150

% %%
genes
% Out:
% genes =
%
%   1x134 cell array
%
%   Columns 1 through 6
%
%     {'LDHAL6A'}    {'LDHA'}    {'LDHB'}    {'LDHC'}    {'UEVLD'}    {'LDHAL6B'}
%
%   Columns 7 through 12
%
%     {'DLD'}    {'DLST'}    {'OGDH'}    {'PDHX'}    {'ADH1A'}    {'ADH1B'}
%
%   Columns 13 through 18
%
%     {'ADH1C'}    {'ADH4'}    {'ADH5'}    {'ADH6'}    {'ADH7'}    {'ADHFE1'}
%
%   Columns 19 through 23
%
%     {'ALDH3A1'}    {'ALDH1A3'}    {'ALDH3B1'}    {'ALDH3B2'}    {'ALDH4A1'}
%
%   Columns 24 through 28
%
%     {'ALDH2'}    {'ALDH1B1'}    {'ZADH2'}    {'ALDH1A1'}    {'ALDH9A1'}
%
%   Columns 29 through 33
%
%     {'ALDH3A2'}    {'ALDH7A1'}    {'ALDH1A2'}    {'BDH1'}    {'ACADM'}
%
%   Columns 34 through 38
%
%     {'ACADS'}    {'ALDH1L1'}    {'ALDH6A1'}    {'ALDH18A1'}    {'ALDH5A1'}
%
%   Columns 39 through 44
%
%     {'GCSH'}    {'GLDC'}    {'AMT'}    {'GLUD1'}    {'GLUD2'}    {'HSD17B10'}
%
%   Columns 45 through 49
%
%     {'HADHA'}    {'HADHB'}    {'HADH'}    {'EHHADH'}    {'HIBADH'}
%
%   Columns 50 through 55
%
%     {'HSD3B1'}    {'IDH3A'}    {'IDH3B'}    {'IDH3G'}    {'LDHD'}    {'MAOB'}
%
%   Columns 56 through 61
%
%     {'MDH1'}    {'MDH2'}    {'ME2'}    {'MTHFD2'}    {'DBT'}    {'BCKDHA'}
%
%   Columns 62 through 67
%
%     {'BCKDHB'}    {'DLAT'}    {'PDHA1'}    {'PDHA2'}    {'PDHB'}    {'PHGDH'}
%
%   Columns 68 through 73
%
%     {'PRODH'}    {'RDH5'}    {'RDH16'}    {'SORD'}    {'MDH1B'}    {'UGDH'}
%
%   Columns 74 through 79
%
%     {'GSR'}    {'XDH'}    {'CMAHP'}    {'IDH1'}    {'IDH2'}    {'DHFR'}
%
%   Columns 80 through 84
%
%     {'AASS'}    {'PYCR2'}    {'PYCR1'}    {'HSD17B4'}    {'HSD3B2'}
%
%   Columns 85 through 90
%
%     {'CYP27A1'}    {'CBR1'}    {'CBR3'}    {'DHRS4'}    {'ACAA2'}    {'ECHS1'}
%
%   Columns 91 through 96
%
%     {'ACADVL'}    {'HPGD'}    {'GPD1'}    {'GAPDH'}    {'GAPDHS'}    {'IMPDH1'}
%
%   Columns 97 through 101
%
%     {'IMPDH2'}    {'PRODH2'}    {'MTHFR'}    {'MTHFD2P1'}    {'MTHFD2L'}
%
%   Columns 102 through 106
%
%     {'ACOT8'}    {'ACOT2'}    {'SLC27A4'}    {'SLC27A3'}    {'SLC27A2'}
%
%   Columns 107 through 112
%
%     {'ACOT7'}    {'ACOT4'}    {'AASDH'}    {'ACSF3'}    {'AMACR'}    {'ACAA1'}
%
%   Columns 113 through 117
%
%     {'LOC344967'}    {'SLC27A1'}    {'ACOX1'}    {'BAAT'}    {'ACOT1'}
%
%   Columns 118 through 122
%
%     {'ACSF2'}    {'ACOX3'}    {'PTGR1'}    {'TECRL'}    {'HSD17B12'}
%
%   Columns 123 through 128
%
%     {'AKR1C3'}    {'NSDHL'}    {'HSD3B7'}    {'ACAD9'}    {'ACADL'}    {'CHDH'}
%
%   Columns 129 through 134
%
%     {'ECI2'}    {'ECI1'}    {'DECR1'}    {'DECR2'}    {'NQO1'}    {'NQO2'}
